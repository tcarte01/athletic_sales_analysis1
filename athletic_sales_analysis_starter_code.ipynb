# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Import Libraries and Dependencies
import pandas as pd

# %%
# Read the CSV files into DataFrame
athletic_2020 = pd.read_csv('Resources/athletic_sales_2020.csv')
athletic_2021 = pd.read_csv('Resources/athletic_sales_2021.csv')

# %%
# Display the 2020 sales DataFrame
athletic_2020.head()
# Out:
#       retailer  retailer_id invoice_date     region         state  \
# 0  Foot Locker      1185732       1/1/20  Northeast      New York
# 1  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3  Foot Locker      1185732       1/1/20  Northeast      New York
# 4  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
#
#            city                product  price_per_unit  units_sold  \
# 0      New York  Men's Street Footwear              50        1200
# 1  Philadelphia        Women's Apparel              68          83
# 2  Philadelphia        Women's Apparel              75         275
# 3      New York  Men's Street Footwear              34         384
# 4  Philadelphia        Women's Apparel              53          83
#
#    total_sales  operating_profit sales_method
# 0       600000         300000.00     In-store
# 1         5644           2426.92       Online
# ...

# %%
# Display the 2021 sales DataFrame
athletic_2021.head()
# Out:
#     retailer  retailer_id invoice_date   region       state           city  \
# 0  West Gear      1128299       1/1/21     West  California  San Francisco
# 1  West Gear      1128299       1/1/21     West  California  San Francisco
# 2     Kohl's      1189833       1/1/21  Midwest     Montana       Billings
# 3     Kohl's      1189833       1/1/21  Midwest     Montana       Billings
# 4  West Gear      1128299       1/1/21     West  California  San Francisco
#
#                    product  price_per_unit  units_sold  total_sales  \
# 0  Men's Athletic Footwear              65         750       487500
# 1  Men's Athletic Footwear              51         233        11883
# 2            Men's Apparel              50         275       137500
# 3            Men's Apparel              47          77         3619
# 4  Men's Athletic Footwear              64         225        14400
#
#    operating_profit sales_method
# 0         121875.00       Outlet
# 1           3208.41       Outlet
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
athletic_2020.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
athletic_2021.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
athletic_2020_2021_df = pd.concat([athletic_2020, athletic_2021], axis=0)
athletic_2020_2021_df.head()
athletic_2020_2021_df.reset_index()
# Out:
#       index     retailer  retailer_id invoice_date     region         state  \
# 0         0  Foot Locker      1185732       1/1/20  Northeast      New York
# 1         1  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2         2  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3         3  Foot Locker      1185732       1/1/20  Northeast      New York
# 4         4  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...     ...          ...          ...          ...        ...           ...
# 9638   8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9639   8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9640   8343       Amazon      1185732     12/31/21  Northeast         Maine
# 9641   8344       Amazon      1185732     12/31/21  Northeast         Maine
# 9642   8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
# ...

# %%
# Check if any values are null
null_values = athletic_2020_2021_df.isnull()
null_values
# Out:
#       retailer  retailer_id  invoice_date  region  state   city  product  \
# 0        False        False         False   False  False  False    False
# 1        False        False         False   False  False  False    False
# 2        False        False         False   False  False  False    False
# 3        False        False         False   False  False  False    False
# 4        False        False         False   False  False  False    False
# ...        ...          ...           ...     ...    ...    ...      ...
# 8341     False        False         False   False  False  False    False
# 8342     False        False         False   False  False  False    False
# 8343     False        False         False   False  False  False    False
# 8344     False        False         False   False  False  False    False
# 8345     False        False         False   False  False  False    False
#
#       price_per_unit  units_sold  total_sales  operating_profit  sales_method
# ...

# %%
# Check the data type of each column
column_type = athletic_2020_2021_df.dtypes
column_type
# Out:
# retailer                    object
# retailer_id                  int64
# invoice_date        datetime64[ns]
# region                      object
# state                       object
# city                        object
# product                     object
# price_per_unit               int64
# units_sold                   int64
# total_sales                  int64
# operating_profit           float64
# sales_method                object
# dtype: object

# %%
# Convert the "invoice_date" to a datetime
athletic_2020_2021_df['invoice_date']= pd.to_datetime(athletic_2020_2021_df['invoice_date'])

# %%
# Confirm that the "invoice_date" data type has been changed.
athletic_2020_2021_df.dtypes
# Out:
# retailer                    object
# retailer_id                  int64
# invoice_date        datetime64[ns]
# region                      object
# state                       object
# city                        object
# product                     object
# price_per_unit               int64
# units_sold                   int64
# total_sales                  int64
# operating_profit           float64
# sales_method                object
# dtype: object

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".
athletic_sales_sum = athletic_2020_2021_df.groupby(['region', 'state', 'city']).agg({'units_sold': 'sum'})
athletic_sales_sum.rename(columns={'units_sold': 'Total_Products_Sold'}, inplace=True)

df_sorted = athletic_sales_sum.sort_values('Total_Products_Sold', ascending = False)

# Show the top 5 results.
df_sorted.head(5)
# Out:
#                                     Total_Products_Sold
# region    state      city
# Northeast New York   New York                    111954
# South     Texas      Houston                      90322
# West      California San Francisco                85478
#                      Los Angeles                  76384
# Southeast Florida    Miami                        73135

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
athletic_sales_sum_pivot = pd.pivot_table(athletic_2020_2021_df, values = 'units_sold', index = ['region', 'state', 'city'], aggfunc = 'sum')

# Rename the "units_sold" column to "Total_Products_Sold"
athletic_sales_sum_pivot.rename(columns={'units_sold': 'Total_Products_Sold'}, inplace=True)
df_sort = athletic_sales_sum_pivot.sort_values('Total_Products_Sold', ascending = False)

# Show the top 5 results.
df_sort.head(5)
# Out:
#                                     Total_Products_Sold
# region    state      city
# Northeast New York   New York                    111954
# South     Texas      Houston                      90322
# West      California San Francisco                85478
#                      Los Angeles                  76384
# Southeast Florida    Miami                        73135

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
# Rename the "total_sales" column to "Total Sales"
athletic_sales_sum = athletic_2020_2021_df.groupby(['region', 'state', 'city']).agg({'total_sales': 'sum'})
athletic_sales_sum.rename(columns={'total_sales': 'Total Sales'}, inplace=True)

df_sorted = athletic_sales_sum.sort_values('Total Sales', ascending = False)
# Show the top 5 results.
df_sorted.head(5)
# Out:
#                                         Total Sales
# region    state          city
# Northeast New York       New York          39801235
# West      California     San Francisco     33973228
# Southeast Florida        Miami             31600863
#           South Carolina Charleston        29285637
#           Florida        Orlando           27682851

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.
athletic_sales_sum_pivot = pd.pivot_table(athletic_2020_2021_df, values = 'total_sales', index = ['region', 'state', 'city'], aggfunc = 'sum')

# Optional: Rename the "total_sales" column to "Total Sales"
athletic_sales_sum_pivot.rename(columns={'total_sales': 'Total Sales'}, inplace=True)
df_sort = athletic_sales_sum_pivot.sort_values('Total Sales', ascending = False)
# Show the top 5 results.
df_sort.head(5)
# Out:
#                                         Total Sales
# region    state          city
# Northeast New York       New York          39801235
# West      California     San Francisco     33973228
# Southeast Florida        Miami             31600863
#           South Carolina Charleston        29285637
#           Florida        Orlando           27682851

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
# Rename the "total_sales" column to "Total Sales"
athletic_sales_sum = athletic_2020_2021_df.groupby(['retailer','region', 'state', 'city']).agg({'total_sales': 'sum'})
athletic_sales_sum.rename(columns={'total_sales': 'Total Sales'}, inplace=True)

df_sorted = athletic_sales_sum.sort_values('Total Sales', ascending = False)
# Show the top 5 results.
df_sorted.head(5)
# Out:
#                                                     Total Sales
# retailer    region    state          city
# West Gear   West      California     San Francisco     32794405
# Kohl's      West      California     Los Angeles       25127160
# Foot Locker Northeast New York       New York          25008568
# West Gear   West      Washington     Seattle           24862675
# Foot Locker Southeast South Carolina Charleston        24822280

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
athletic_sales_sum_pivot = pd.pivot_table(athletic_2020_2021_df, values = 'total_sales', index = ['retailer','region', 'state', 'city'], aggfunc = 'sum')

# Optional: Rename the "total_sales" column to "Total Sales"
athletic_sales_sum_pivot.rename(columns={'total_sales': 'Total Sales'}, inplace=True)
df_sort = athletic_sales_sum_pivot.sort_values('Total Sales', ascending = False)

# Show the top 5 results.
df_sort.head(5)
# Out:
#                                                     Total Sales
# retailer    region    state          city
# West Gear   West      California     San Francisco     32794405
# Kohl's      West      California     Los Angeles       25127160
# Foot Locker Northeast New York       New York          25008568
# West Gear   West      Washington     Seattle           24862675
# Foot Locker Southeast South Carolina Charleston        24822280

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
women_shoes_data = athletic_2020_2021_df[athletic_2020_2021_df['product'].str.contains("Women's Apparel")]

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
athletic_sales_sum = women_shoes_data.groupby(['retailer','region', 'state', 'city']).agg({'units_sold': 'sum'})

athletic_sales_sum.rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'}, inplace=True)

df_sorted = athletic_sales_sum.sort_values('Womens_Footwear_Units_Sold', ascending = False)
# Show the top 5 results.
df_sorted.head(5)
# Out:
#                                                Womens_Footwear_Units_Sold
# retailer      region state      city
# West Gear     West   California San Francisco                       14480
# Sports Direct South  Texas      Dallas                              13056
# Kohl's        West   California Los Angeles                         12968
# Walmart       South  Texas      Houston                             12797
# Sports Direct South  Tennessee  Knoxville                           12345

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
athletic_sales_sum_pivot = pd.pivot_table(women_shoes_data, values = 'units_sold', index = ['retailer','region', 'state', 'city'], aggfunc = 'sum')

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
athletic_sales_sum_pivot.rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'}, inplace=True)
df_sort = athletic_sales_sum_pivot.sort_values('Womens_Footwear_Units_Sold', ascending = False)
# Show the top 5 results.
df_sort.head(5)
# Out:
#                                                Womens_Footwear_Units_Sold
# retailer      region state      city
# West Gear     West   California San Francisco                       14480
# Sports Direct South  Texas      Dallas                              13056
# Kohl's        West   California Los Angeles                         12968
# Walmart       South  Texas      Houston                             12797
# Sports Direct South  Tennessee  Knoxville                           12345

# %% [markdown]
# ### 5. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
womens_athletic_shoes_df = pd.pivot_table(women_shoes_data, values = 'total_sales', index = 'invoice_date',)

# Optional: Rename the "total_sales" column to "Total Sales"


# Show the table.
womens_athletic_shoes_df
# Out:
#                 total_sales
# invoice_date
# 2020-01-01     72097.666667
# 2020-01-06    174833.333333
# 2020-01-07     74991.333333
# 2020-01-13     63032.000000
# 2020-01-19     72054.000000
# ...                     ...
# 2021-12-21    108761.000000
# 2021-12-22     94545.000000
# 2021-12-23    171087.666667
# 2021-12-25    137623.333333
# 2021-12-26     79200.800000
#
# [355 rows x 1 columns]

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.
resample_df

# Sort the resampled pivot table in ascending order on "Total Sales".

# %% [markdown]
# ### 6.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.


# Sort the resampled pivot table in ascending order on "Total Sales".
